# %% [markdown]
# ## 数据集Dataloader制作
# ![title](img/DataLoader.png)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
import torch.optim as optim
import torchvision
#pip install torchvision
from torchvision import transforms, models, datasets
#https://pytorch.org/docs/stable/torchvision/index.html
import imageio
import time
import warnings
import random
import sys
import copy
import json
from PIL import Image

# %% [markdown]
# #### 任务1：读取txt文件中的路径和标签

# %%
def load_annotations(ann_file):
    data_infos = {}
    with open(ann_file) as f:
        samples = [x.strip().split(' ') for x in f.readlines()]
        for filename, gt_label in samples:
            data_infos[filename] = np.array(gt_label, dtype=np.int64)
    return data_infos

# %%
print(load_annotations('./flower_data/train.txt'))
# Out:
# {'image_06734.jpg': array(0, dtype=int64), 'image_06735.jpg': array(0, dtype=int64), 'image_06736.jpg': array(0, dtype=int64), 'image_06737.jpg': array(0, dtype=int64), 'image_06738.jpg': array(0, dtype=int64), 'image_06740.jpg': array(0, dtype=int64), 'image_06741.jpg': array(0, dtype=int64), 'image_06742.jpg': array(0, dtype=int64), 'image_06744.jpg': array(0, dtype=int64), 'image_06745.jpg': array(0, dtype=int64), 'image_06746.jpg': array(0, dtype=int64), 'image_06747.jpg': array(0, dtype=int64), 'image_06748.jpg': array(0, dtype=int64), 'image_06750.jpg': array(0, dtype=int64), 'image_06751.jpg': array(0, dtype=int64), 'image_06753.jpg': array(0, dtype=int64), 'image_06757.jpg': array(0, dtype=int64), 'image_06759.jpg': array(0, dtype=int64), 'image_06761.jpg': array(0, dtype=int64), 'image_06762.jpg': array(0, dtype=int64), 'image_06766.jpg': array(0, dtype=int64), 'image_06767.jpg': array(0, dtype=int64), 'image_06768.jpg': array(0, dtype=int64), 'image_06770.jpg': array(0, dtype=int64), 'image_06771.jpg': array(0, dtype=int64), 'image_06772.jpg': array(0, dtype=int64), 'image_06773.jpg': array(0, dtype=int64), 'image_07086.jpg': array(9, dtype=int64), 'image_07087.jpg': array(9, dtype=int64), 'image_07088.jpg': array(9, dtype=int64), 'image_07089.jpg': array(9, dtype=int64), 'image_07091.jpg': array(9, dtype=int64), 'image_07092.jpg': array(9, dtype=int64), 'image_07093.jpg': array(9, dtype=int64), 'image_07095.jpg': array(9, dtype=int64), 'image_07096.jpg': array(9, dtype=int64), 'image_07097.jpg': array(9, dtype=int64), 'image_07098.jpg': array(9, dtype=int64), 'image_07099.jpg': array(9, dtype=int64), 'image_07100.jpg': array(9, dtype=int64), 'image_07103.jpg': array(9, dtype=int64), 'image_07105.jpg': array(9, dtype=int64), 'image_07106.jpg': array(9, dtype=int64), 'image_07108.jpg': array(9, dtype=int64), 'image_07109.jpg': array(9, dtype=int64), 'image_07110.jpg': array(9, dtype=int64), 'image_07111.jpg': array(9, dtype=int64), 'image_07112.jpg': array(9, dtype=int64), 'image_07113.jpg': array(9, dtype=int64), 'image_07114.jpg': array(9, dtype=int64), 'image_07115.jpg': array(9, dtype=int64), 'image_07116.jpg': array(9, dtype=int64), 'image_07118.jpg': array(9, dtype=int64), 'image_07119.jpg': array(9, dtype=int64), 'image_07120.jpg': array(9, dtype=int64), 'image_07121.jpg': array(9, dtype=int64), 'image_07122.jpg': array(9, dtype=int64), 'image_08090.jpg': array(9, dtype=int64), 'image_08091.jpg': array(9, dtype=int64), 'image_08092.jpg': array(9, dtype=int64), 'image_08093.jpg': array(9, dtype=int64), 'image_08094.jpg': array(9, dtype=int64), 'image_08095.jpg': array(9, dtype=int64), 'image_08096.jpg': array(9, dtype=int64), 'image_08097.jpg': array(9, dtype=int64), 'image_07893.jpg': array(99, dtype=int64), 'image_07894.jpg': array(99, dtype=int64), 'image_07898.jpg': array(99, dtype=int64), 'image_07900.jpg': array(99, dtype=int64), 'image_07901.jpg': array(99, dtype=int64), 'image_07903.jpg': array(99, dtype=int64), 'image_07906.jpg': array(99, dtype=int64), 'image_07907.jpg': array(99, dtype=int64), 'image_07908.jpg': array(99, dtype=int64), 'image_07909.jpg': array(99, dtype=int64), 'image_07910.jpg': array(99, dtype=int64), 'image_07911.jpg': array(99, dtype=int64), 'image_07912.jpg': array(99, dtype=int64), 'image_07913.jpg': array(99, dtype=int64), 'image_07914.jpg': array(99, dtype=int64), 'image_07915.jpg': array(99, dtype=int64), 'image_07916.jpg': array(99, dtype=int64), 'image_07918.jpg': array(99, dtype=int64), 'image_07919.jpg': array(99, dtype=int64), 'image_07920.jpg': array(99, dtype=int64), 'image_07921.jpg': array(99, dtype=int64), 'image_07922.jpg': array(99, dtype=int64), 'image_07923.jpg': array(99, dtype=int64), 'image_07924.jpg': array(99, dtype=int64), 'image_07925.jpg': array(99, dtype=int64), 'image_07927.jpg': array(99, dtype=int64), 'image_07928.jpg': array(99, dtype=int64), 'image_07930.jpg': array(99, dtype=int64), 'image_07932.jpg': array(99, dtype=int64), 'image_07933.jpg': arr ...

# %% [markdown]
# #### 任务2：分别把数据和标签都存在list里

# %%
image_label = load_annotations('./flower_data/train.txt')
image_name = list(image_label.keys())
label = list(image_label.values())

# %%
image_name
# Out:
# ['image_06734.jpg',
#  'image_06735.jpg',
#  'image_06736.jpg',
#  'image_06737.jpg',
#  'image_06738.jpg',
#  'image_06740.jpg',
#  'image_06741.jpg',
#  'image_06742.jpg',
#  'image_06744.jpg',
#  'image_06745.jpg',
#  'image_06746.jpg',
#  'image_06747.jpg',
#  'image_06748.jpg',
#  'image_06750.jpg',
#  'image_06751.jpg',
#  'image_06753.jpg',
#  'image_06757.jpg',
#  'image_06759.jpg',
#  'image_06761.jpg',
#  'image_06762.jpg',
#  'image_06766.jpg',
#  'image_06767.jpg',
#  'image_06768.jpg',
#  'image_06770.jpg',
#  'image_06771.jpg',
#  'image_06772.jpg',
#  'image_06773.jpg',
#  'image_07086.jpg',
#  'image_07087.jpg',
#  'image_07088.jpg',
#  'image_07089.jpg',
#  'image_07091.jpg',
#  'image_07092.jpg',
#  'image_07093.jpg',
#  'image_07095.jpg',
#  'image_07096.jpg',
#  'image_07097.jpg',
#  'image_07098.jpg',
#  'image_07099.jpg',
#  'image_07100.jpg',
#  'image_07103.jpg',
#  'image_07105.jpg',
#  'image_07106.jpg',
#  'image_07108.jpg',
#  'image_07109.jpg',
#  'image_07110.jpg',
#  'image_07111.jpg',
#  'image_07112.jpg',
#  'image_07113.jpg',
#  'image_07114.jpg',
#  'image_07115.jpg',
#  'image_07116.jpg',
#  'image_07118.jpg',
#  'image_07119.jpg',
#  'image_07120.jpg',
#  'image_07121.jpg',
#  'image_07122.jpg',
#  'image_08090.jpg',
#  'image_08091.jpg',
#  'image_08092.jpg',
#  'image_08093.jpg',
#  'image_08094.jpg',
#  'image_08095.jpg',
#  'image_08096.jpg',
#  'image_08097.jpg',
#  'image_07893.jpg',
#  'image_07894.jpg',
#  'image_07898.jpg',
#  'image_07900.jpg',
#  'image_07901.jpg',
#  'image_07903.jpg',
#  'image_07906.jpg',
#  'image_07907.jpg',
#  'image_07908.jpg',
#  'image_07909.jpg',
#  'image_07910.jpg',
#  'image_07911.jpg',
#  'image_07912.jpg',
#  'image_07913.jpg',
#  'image_07914.jpg',
#  'image_07915.jpg',
#  'image_07916.jpg',
#  'image_07918.jpg',
#  'image_07919.jpg',
#  'image_07920.jpg',
#  'image_07921.jpg',
#  'image_07922.jpg',
#  'image_07923.jpg',
#  'image_07924.jpg',
#  'image_07925.jpg',
#  'image_07927.jpg',
#  'image_07928.jpg',
#  'image_07930.jpg',
#  'image_07932.jpg',
#  'image_07933.jpg',
#  'image_07934.jpg',
#  'image_07935.jpg',
#  'image_07937.jpg',
#  'image_07940.jpg',
#  'image_07941.jpg',
#  'image_07942.jpg',
#  'image_07943.jpg',
#  'image_07944.jpg',
#  'image_07945.jpg',
#  'image_07946.jpg',
#  'image_07947.jpg',
#  'image_07948.jpg',
#  'image_07950.jpg',
#  'image_07953.jpg',
#  'image_07954.jpg',
#  'image_07955.jpg',
#  'image_07956.jpg',
#  'image_07957.jpg',
#  'image_07958.jpg',
#  'image_07959.jpg',
#  'image_07960.jpg',
#  'image_07961.jpg',
#  'image_07964.jpg',
#  'image_07965.jpg',
#  'image_07966.jpg',
#  'image_07967.jpg',
#  'image_07968.jpg',
#  'image_07969.jpg',
#  'image_07971.jpg',
#  'image_07972.jpg',
#  'image_07973.jpg',
#  'image_07974.jpg',
#  'image_07975.jpg',
#  'image_07976.jpg',
#  'image_07977.jpg',
#  'image_07978.jpg',
#  'image_07979.jpg',
#  'image_07980.jpg',
#  'image_07981.jpg',
#  'image_07982.jpg',
#  'image_07984.jpg',
#  'image_07986.jpg',
#  'image_07987.jpg',
#  'image_07989.jpg',
#  'image_07990.jpg',
#  'image_07991.jpg',
#  'image_07992.jpg',
#  'image_07993.jpg',
#  'image_07994.jpg',
#  'image_07995.jpg',
#  'image_07996.jpg',
#  'image_07997.jpg',
#  'image_07998.jpg',
#  'image_07999.jpg',
#  'image_08000.jpg',
#  'image_08001.jpg',
#  'image_08003.jpg',
#  'image_08005.jpg',
#  'image_08007.jpg',
#  'image_08008.jpg',
#  'image_08009.jpg',
#  'image_08010.jpg',
#  'image_08011.jpg',
#  'image_08013.jpg',
#  'image_08016.jpg',
#  'image_08017.jpg',
#  'image_08018.jpg',
#  'image_08019.jpg',
#  'image_08020.jpg',
#  'image_08021.jpg',
#  'image_08022.jpg',
#  'image_08024.jpg',
#  'image_08025.jpg',
#  'image_08026.jpg',
#  'image_08027.jpg',
#  'image_08028.jpg',
#  'image_08029.jpg',
#  'image_08031.jpg',
#  'image_08032.jpg',
#  'image_08033.jpg',
#  'image_08034.jpg',
#  'image_08035.jpg',
#  'image_08036.jpg',
#  'image_08037.jpg',
#  'image_08039.jpg',
#  'image_08043.jpg',
#  'image_08044.jpg',
#  'image_08045.jpg',
#  'image_08046.jpg',
#  'image_08047.jpg',
#  'image_03095.jpg',
#  'image_03096.jpg',
#  'image_03097.jpg',
#  'image_03099.jpg',
#  'image_03101.jpg',
#  'image_03102.jpg',
#  'image_03103.jpg',
#  'image_03104.jpg',
#  'image_03105.jpg',
#  'image_03106.jpg',
#  'image_03107.jpg',
#  'image_03109.jpg',
#  'image_03110.jpg',
#  'image_03112.jpg',
#  'image_03113.jpg',
#  'image_03114.jpg',
#  'image_03117.jpg',
#  'image_03118.jpg',
#  'image_03119.jpg',
#  'image_03120.jpg',
#  'image_03121.jpg',
#  'image_03122.jpg',
#  'image_03123.jpg',
#  'image_03124.jpg',
#  'image_03126.jpg',
#  'image_03127.jpg',
#  'image_03129.jpg',
#  'image_03131.jpg',
#  'image_03132.jpg',
#  'image_03133.jpg',
#  'image_03134.jpg',
#  'image_03135.jpg',
#  'image_03136.jpg',
#  'image_03137.jpg',
#  'image_03138.jpg',
#  'image_03140.jpg',
#  'image_03142.jpg',
#  'image_03143.jpg',
#  'image_03144.jpg',
#  'image_03146.jpg',
#  'image_03148.jpg',
#  'image_03149.jpg',
#  'image_03150.jpg',
#  'image_03152.jpg',
#  'image_03153.jpg',
#  'image_03154.jpg',
#  'image_03155.jpg',
#  'image_03156.jpg',
#  'image_03158.jpg',
#  'image_03159.jpg',
#  'image_03160.jpg',
#  'image_03161.jpg',
#  'image_03162.jpg',
#  'image_03163.jpg',
#  'image_03164.jpg',
#  'image_03166.jpg',
#  'image_03167.jpg',
#  'image_03168.jpg',
#  'image_03169.jpg',
#  'image_03170.jpg',
#  'image_03171.jpg',
#  'image_03172.jpg',
#  'image_03174.jpg',
#  'image_03175.jpg',
#  'image_03178.jpg',
#  'image_03179.jpg',
#  'image_03180.jpg',
#  'image_03181.jpg',
#  'image_03995.jpg',
#  'image_03999.jpg',
#  'image_04000.jpg',
#  'image_04001.jpg',
#  'image_04002.jpg',
#  'image_04003.jpg',
#  'image_04004.jpg',
#  'image_04005.jpg',
#  'image_04006.jpg',
#  'image_04007.jpg',
#  'image_04008.jpg',
#  'image_04009.jpg',
#  'image_04010.jpg',
#  'image_04011.jpg',
#  'image_04015.jpg',
#  'image_04017.jpg',
#  'image_04018.jpg',
#  'image_04019.jpg',
#  'image_04020.jpg',
#  'image_04021.jpg',
#  'image_04022.jpg',
#  'image_04024.jpg',
#  'image_04025.jpg',
#  'image_04026.jpg',
#  'image_04027.jpg',
#  'image_04028.jpg',
#  'image_04029.jpg',
#  'image_04030.jpg',
#  'image_04031.jpg',
#  'image_04032.jpg',
#  'image_04033.jpg',
#  'image_04034.jpg',
#  'image_04035.jpg',
#  'image_04036.jpg',
#  'image_04037.jpg',
#  'image_04038.jpg',
#  'image_04039.jpg',
#  'image_04040.jpg',
#  'image_04041.jpg',
#  'image_04042.jpg',
#  'image_04043.jpg',
#  'image_04044.jpg',
#  'image_04045.jpg',
#  'image_04046.jpg',
#  'image_04047.jpg',
#  'image_04048.jpg',
#  'image_04049.jpg',
#  'image_04050.jpg',
#  'image_04051.jpg',
#  'image_04053.jpg',
#  'image_04054.jpg',
#  'image_04055.jpg',
#  'image_04056.jpg',
#  'image_04057.jpg',
#  'image_04058.jpg',
#  'image_04060.jpg',
#  'image_04061.jpg',
#  'image_04062.jpg',
#  'image_04063.jpg',
#  'image_04064.jpg',
#  'image_04065.jpg',
#  'image_04066.jpg',
#  'image_04067.jpg',
#  'image_04068.jpg',
#  'image_04069.jpg',
#  'image_04070.jpg',
#  'image_04071.jpg',
#  'image_04073.jpg',
#  'image_04074.jpg',
#  'image_04075.jpg',
#  'image_04076.jpg',
#  'image_04078.jpg',
#  'image_04079.jpg',
#  'image_05744.jpg',
#  'image_05746.jpg',
#  'image_05747.jpg',
#  'image_05748.jpg',
#  'image_05750.jpg',
#  'image_05751.jpg',
#  'image_05752.jpg',
#  'image_05753.jpg',
#  'image_05754.jpg',
#  'image_05755.jpg',
#  'image_05756.jpg',
#  'image_05757.jpg',
#  'image_05758.jpg',
#  'image_05760.jpg',
#  'image_05762.jpg',
#  'image_05764.jpg',
#  'image_05765.jpg',
#  'image_05766.jpg',
#  'image_05768.jpg',
#  'image_05770.jpg',
#  'image_05771.jpg',
#  'image_05773.jpg',
#  'image_05774.jpg',
#  'image_05776.jpg',
#  'image_05777.jpg',
#  'image_05778.jpg',
#  'image_05779.jpg',
#  'image_05780.jpg',
#  'image_05781.jpg',
#  'image_05782.jpg',
#  'image_05784.jpg',
#  'image_05785.jpg',
#  'image_05786.jpg',
#  'image_05788.jpg',
#  'image_05789.jpg',
#  'image_05790.jpg',
#  'image_05791.jpg',
#  'image_05792.jpg',
#  'image_06049.jpg',
#  'image_06050.jpg',
#  'image_06051.jpg',
#  'image_06053.jpg',
#  'image_06054.jpg',
#  'image_06055.jpg',
#  'image_06056.jpg',
#  'image_06057.jpg',
#  'image_06058.jpg',
#  'image_06059.jpg',
#  'image_06060.jpg',
#  'image_06061.jpg',
#  'image_06062.jpg',
#  'image_06063.jpg',
#  'image_06064.jpg',
#  'image_06065.jpg',
#  'image_06066.jpg',
#  'image_06067.jpg',
#  'image_06068.jpg',
#  'image_06069.jpg',
#  'image_06070.jpg',
#  'image_06071.jpg',
#  'image_06072.jpg',
#  'image_06073.jpg',
#  'image_06074.jpg',
#  'image_06075.jpg',
#  'image_06076.jpg',
#  'image_06077.jpg',
#  'image_06078.jpg',
#  'image_06079.jpg',
#  'image_06080.jpg',
#  'image_06081.jpg',
#  'image_06084.jpg',
#  'image_06085.jpg',
#  'image_06086.jpg',
#  'image_06087.jpg',
#  'image_06088.jpg',
#  'image_06089.jpg',
#  'image_06090.jpg',
#  'image_06092.jpg',
#  'image_06093.jpg',
#  'image_06094.jpg',
#  'image_06095.jpg',
#  'image_06096.jpg',
#  'image_06347.jpg',
#  'image_06348.jpg',
#  'image_06349.jpg',
#  'image_06350.jpg',
#  'image_06352.jpg',
#  'image_06355.jpg',
#  'image_06356.jpg',
#  'image_06357.jpg',
#  'image_06359.jpg',
#  'image_06361.jpg',
#  'image_06362.jpg',
#  'image_06363.jpg',
#  'image_06364.jpg',
#  'image_06365.jpg',
#  'image_06366.jpg',
#  'image_06367.jpg',
#  'image_06368.jpg',
#  'image_06370.jpg',
#  'image_06371.jpg',
#  'image_06372.jpg',
#  'image_06373.jpg',
#  'image_06375.jpg',
#  'image_06376.jpg',
#  'image_06377.jpg',
#  'image_06378.jpg',
#  'image_06379.jpg',
#  'image_06380.jpg',
#  'image_06381.jpg',
#  'image_06382.jpg',
#  'image_06383.jpg',
#  'image_06384.jpg',
#  'image_06387.jpg',
#  'image_06388.jpg',
#  'image_06390.jpg',
#  'image_06391.jpg',
#  'image_06392.jpg',
#  'image_06393.jpg',
#  'image_06394.jpg',
#  'image_06652.jpg',
#  'image_06653.jpg',
#  'image_06654.jpg',
#  'image_06655.jpg',
#  'image_06656.jpg',
#  'image_06658.jpg',
#  'image_06659.jpg',
#  'image_06660.jpg',
#  'image_06661.jpg',
#  'image_06662.jpg',
#  'image_06663.jpg',
#  'image_06664.jpg',
#  'image_06665.jpg',
#  'image_06666.jpg',
#  'image_06667.jpg',
#  'image_06668.jpg',
#  'image_06669.jpg',
#  'image_06672.jpg',
#  'image_06674.jpg',
#  'image_06675.jpg',
#  'image_06676.jpg',
#  'image_06677.jpg',
#  'image_06678.jpg',
#  'image_06679.jpg',
#  'image_06680.jpg',
#  'image_06681.jpg',
#  'image_06682.jpg',
#  'image_06683.jpg',
#  'image_06684.jpg',
#  'image_06685.jpg',
#  'image_06686.jpg',
#  'image_06687.jpg',
#  'image_06688.jpg',
#  'image_06689.jpg',
#  'image_06690.jpg',
#  'image_06692.jpg',
#  'image_03828.jpg',
#  'image_03832.jpg',
#  'image_03833.jpg',
#  'image_03835.jpg',
#  'image_03836.jpg',
#  'image_03838.jpg',
#  'image_03840.jpg',
#  'image_03841.jpg',
#  'image_03844.jpg',
#  'image_03845.jpg',
#  'image_03847.jpg',
#  'image_03848.jpg',
#  'image_03849.jpg',
#  'image_03850.jpg',
#  'image_03852.jpg',
#  'image_03853.jpg',
#  'image_03857.jpg',
#  'image_03858.jpg',
#  'image_03859.jpg',
#  'image_03860.jpg',
#  'image_03862.jpg',
#  'image_03863.jpg',
#  'image_03865.jpg',
#  'image_03866.jpg',
#  'image_03867.jpg',
#  'image_03869.jpg',
#  'image_03870.jpg',
#  'image_03871.jpg',
#  'image_03873.jpg',
#  'image_03874.jpg',
#  'image_03875.jpg',
#  'image_03877.jpg',
#  'image_03878.jpg',
#  'image_03879.jpg',
#  'image_03880.jpg',
#  'image_03881.jpg',
#  'image_03882.jpg',
#  'image_03884.jpg',
#  'image_03885.jpg',
#  'image_03886.jpg',
#  'image_03887.jpg',
#  'image_03888.jpg',
#  'image_03889.jpg',
#  'image_03891.jpg',
#  'image_03892.jpg',
#  'image_03894.jpg',
#  'image_03895.jpg',
#  'image_03896.jpg',
#  'image_03897.jpg',
#  'image_03898.jpg',
#  'image_03899.jpg',
#  'image_03900.jpg',
#  'image_03901.jpg',
#  'image_03902.jpg',
#  'image_03903.jpg',
#  'image_03904.jpg',
#  'image_03905.jpg',
#  'image_03909.jpg',
#  'image_03910.jpg',
#  'image_03912.jpg',
#  'image_04244.jpg',
#  'image_04245.jpg',
#  'image_04246.jpg',
#  'image_04247.jpg',
#  'image_04249.jpg',
#  'image_04250.jpg',
#  'image_04251.jpg',
#  'image_04253.jpg',
#  'image_04255.jpg',
#  'image_04257.jpg',
#  'image_04258.jpg',
#  'image_04259.jpg',
#  'image_04260.jpg',
#  'image_04262.jpg',
#  'image_04264.jpg',
#  'image_04265.jpg',
#  'image_04266.jpg',
#  'image_04267.jpg',
#  'image_04268.jpg',
#  'image_04269.jpg',
#  'image_04270.jpg',
#  'image_04271.jpg',
#  'image_04273.jpg',
#  'image_04274.jpg',
#  'image_04275.jpg',
#  'image_04276.jpg',
#  'image_04279.jpg',
#  'image_04280.jpg',
#  'image_04281.jpg',
#  'image_04282.jpg',
#  'image_04283.jpg',
#  'image_04284.jpg',
#  'image_04285.jpg',
#  'image_04286.jpg',
#  'image_04287.jpg',
#  'image_04288.jpg',
#  'image_04289.jpg',
#  'image_04291.jpg',
#  'image_04293.jpg',
#  'image_04294.jpg',
#  'image_04295.jpg',
#  'image_04296.jpg',
#  'image_04297.jpg',
#  'image_04298.jpg',
#  'image_04300.jpg',
#  'image_04301.jpg',
#  'image_04302.jpg',
#  'image_04303.jpg',
#  'image_04304.jpg',
#  'image_04305.jpg',
#  'image_04306.jpg',
#  'image_04307.jpg',
#  'image_04308.jpg',
#  'image_04309.jpg',
#  'image_04310.jpg',
#  'image_04313.jpg',
#  'image_04314.jpg',
#  'image_04316.jpg',
#  'image_04318.jpg',
#  'image_04319.jpg',
#  'image_04320.jpg',
#  'image_04321.jpg',
#  'image_04323.jpg',
#  'image_04324.jpg',
#  'image_04325.jpg',
#  'image_06149.jpg',
#  'image_06150.jpg',
#  'image_06151.jpg',
#  'image_06152.jpg',
#  'image_06153.jpg',
#  'image_06154.jpg',
#  'image_06156.jpg',
#  'image_06157.jpg',
#  'image_06160.jpg',
#  'image_06161.jpg',
#  'image_06162.jpg',
#  'image_06163.jpg',
#  'image_06164.jpg',
#  'image_06166.jpg',
#  'image_06167.jpg',
#  'image_06168.jpg',
#  'image_06169.jpg',
#  'image_06171.jpg',
#  'image_06172.jpg',
#  'image_06173.jpg',
#  'image_06174.jpg',
#  'image_06176.jpg',
#  'image_06177.jpg',
#  'image_06178.jpg',
#  'image_06179.jpg',
#  'image_06180.jpg',
#  'image_06181.jpg',
#  'image_06182.jpg',
#  'image_06183.jpg',
#  'image_06184.jpg',
#  'image_06185.jpg',
#  'image_06188.jpg',
#  'image_06189.jpg',
#  'image_06190.jpg',
#  'image_06191.jpg',
#  'image_06192.jpg',
#  'image_06193.jpg',
#  'image_06194.jpg',
#  'image_05087.jpg',
#  'image_05088.jpg',
#  'image_05089.jpg',
#  'image_05090.jpg',
#  'image_05091.jpg',
#  'image_05092.jpg',
#  'image_05093.jpg',
#  'image_05095.jpg',
#  'image_05096.jpg',
#  'image_05097.jpg',
#  'image_05098.jpg',
#  'image_05099.jpg',
#  'image_05102.jpg',
#  'image_05103.jpg',
#  'image_05104.jpg',
#  'image_05105.jpg',
#  'image_05106.jpg',
#  'image_05108.jpg',
#  'image_05110.jpg',
#  'image_05111.jpg',
#  'image_05112.jpg',
#  'image_05113.jpg',
#  'image_05114.jpg',
#  'image_05115.jpg',
#  'image_05116.jpg',
#  'image_05117.jpg',
#  'image_05118.jpg',
#  'image_05119.jpg',
#  'image_05120.jpg',
#  'image_05121.jpg',
#  'image_05122.jpg',
#  'image_05123.jpg',
#  'image_05126.jpg',
#  'image_05127.jpg',
#  'image_05128.jpg',
#  'image_05129.jpg',
#  'image_05130.jpg',
#  'image_05131.jpg',
#  'image_05132.jpg',
#  'image_05134.jpg',
#  'image_05135.jpg',
#  'image_05138.jpg',
#  'image_05139.jpg',
#  'image_05140.jpg',
#  'image_05141.jpg',
#  'image_05143.jpg',
#  'image_05144.jpg',
#  'image_05145.jpg',
#  'image_05146.jpg',
#  'image_04897.jpg',
#  'image_04898.jpg',
#  'image_04899.jpg',
#  'image_04900.jpg',
#  'image_04901.jpg',
#  'image_04902.jpg',
#  'image_04904.jpg',
#  'image_04905.jpg',
#  'image_04906.jpg',
#  'image_04907.jpg',
#  'image_04908.jpg',
#  'image_04909.jpg',
#  'image_04911.jpg',
#  'image_04914.jpg',
#  'image_04915.jpg',
#  'image_04916.jpg',
#  'image_04917.jpg',
#  'image_04919.jpg',
#  'image_04921.jpg',
#  'image_04922.jpg',
#  'image_04923.jpg',
#  'image_04924.jpg',
#  'image_04925.jpg',
#  'image_04926.jpg',
#  'image_04928.jpg',
#  'image_04929.jpg',
#  'image_04930.jpg',
#  'image_04931.jpg',
#  'image_04932.jpg',
#  'image_04933.jpg',
#  'image_04934.jpg',
#  'image_04935.jpg',
#  'image_04936.jpg',
#  'image_04937.jpg',
#  'image_04939.jpg',
#  'image_04941.jpg',
#  'image_04943.jpg',
#  'image_04944.jpg',
#  'image_04945.jpg',
#  'image_04946.jpg',
#  'image_04947.jpg',
#  'image_04948.jpg',
#  'image_04949.jpg',
#  'image_04950.jpg',
#  'image_04951.jpg',
#  'image_04952.jpg',
#  'image_06774.jpg',
#  'image_06775.jpg',
#  'image_06776.jpg',
#  'image_06777.jpg',
#  'image_06779.jpg',
#  'image_06780.jpg',
#  'image_06781.jpg',
#  'image_06782.jpg',
#  'image_06783.jpg',
#  'image_06785.jpg',
#  'image_06786.jpg',
#  'image_06787.jpg',
#  'image_06789.jpg',
#  'image_06790.jpg',
#  'image_06791.jpg',
#  'image_06792.jpg',
#  'image_06793.jpg',
#  'image_06794.jpg',
#  'image_06795.jpg',
#  'image_06796.jpg',
#  'image_06797.jpg',
#  'image_06798.jpg',
#  'image_06799.jpg',
#  'image_06800.jpg',
#  'image_06801.jpg',
#  'image_06802.jpg',
#  'image_06803.jpg',
#  'image_06806.jpg',
#  'image_06808.jpg',
#  'image_06809.jpg',
#  'image_06810.jpg',
#  'image_06811.jpg',
#  'image_06812.jpg',
#  'image_06813.jpg',
#  'image_05340.jpg',
#  'image_05341.jpg',
#  'image_05342.jpg',
#  'image_05343.jpg',
#  'image_05344.jpg',
#  'image_05345.jpg',
#  'image_05346.jpg',
#  'image_05347.jpg',
#  'image_05348.jpg',
#  'image_05349.jpg',
#  'image_05350.jpg',
#  'image_05351.jpg',
#  'image_05353.jpg',
#  'image_05354.jpg',
#  'image_05355.jpg',
#  'image_05356.jpg',
#  'image_05357.jpg',
#  'image_05358.jpg',
#  'image_05359.jpg',
#  'image_05363.jpg',
#  'image_05365.jpg',
#  'image_05367.jpg',
#  'image_05369.jpg',
#  'image_05370.jpg',
#  'image_05371.jpg',
#  'image_05372.jpg',
#  'image_05373.jpg',
#  'image_05374.jpg',
#  'image_05375.jpg',
#  'image_05377.jpg',
#  'image_05378.jpg',
#  'image_05379.jpg',
#  'image_05380.jpg',
#  'image_05382.jpg',
#  'image_05383.jpg',
#  'image_05384.jpg',
#  'image_05385.jpg',
#  'image_05386.jpg',
#  'image_05387.jpg',
#  'image_05389.jpg',
#  'image_05390.jpg',
#  'image_05392.jpg',
#  'image_05393.jpg',
#  'image_05394.jpg',
#  'image_05395.jpg',
#  'image_05396.jpg',
#  'image_05397.jpg',
#  'image_03369.jpg',
#  'image_03370.jpg',
#  'image_03372.jpg',
#  'image_03373.jpg',
#  'image_03374.jpg',
#  'image_03375.jpg',
#  'image_03376.jpg',
#  'image_03377.jpg',
#  'image_03378.jpg',
#  'image_03379.jpg',
#  'image_03380.jpg',
#  'image_03381.jpg',
#  'image_03384.jpg',
#  'image_03385.jpg',
#  'image_03387.jpg',
#  'image_03388.jpg',
#  'image_03389.jpg',
#  'image_03391.jpg',
#  'image_03392.jpg',
#  'image_03393.jpg',
#  'image_03394.jpg',
#  'image_03395.jpg',
#  'image_03396.jpg',
#  'image_03397.jpg',
#  'image_03399.jpg',
#  'image_03401.jpg',
#  'image_03402.jpg',
#  'image_03403.jpg',
#  'image_03404.jpg',
#  'image_03405.jpg',
#  'image_03406.jpg',
#  'image_03407.jpg',
#  'image_03408.jpg',
#  'image_03410.jpg',
#  'image_03411.jpg',
#  'image_03413.jpg',
#  'image_03415.jpg',
#  'image_03417.jpg',
#  'image_03418.jpg',
#  'image_03419.jpg',
#  'image_03421.jpg',
#  'image_03422.jpg',
#  'image_03423.jpg',
#  'image_03424.jpg',
#  'image_03426.jpg',
#  'image_03427.jpg',
#  'image_03428.jpg',
#  'image_03429.jpg',
#  'image_03430.jpg',
#  'image_03431.jpg',
#  'image_03432.jpg',
#  'image_03433.jpg',
#  'image_03434.jpg',
#  'image_03435.jpg',
#  'image_03438.jpg',
#  'image_03439.jpg',
#  'image_03441.jpg',
#  'image_03443.jpg',
#  'image_03445.jpg',
#  'image_03446.jpg',
#  'image_03447.jpg',
#  'image_03448.jpg',
#  'image_03449.jpg',
#  'image_03450.jpg',
#  'image_03451.jpg',
#  'image_03452.jpg',
#  'image_03453.jpg',
#  'image_03455.jpg',
#  'image_03456.jpg',
#  'image_03457.jpg',
#  'image_03458.jpg',
#  'image_03459.jpg',
#  'image_06816.jpg',
#  'image_06817.jpg',
#  'image_06820.jpg',
#  'image_06821.jpg',
#  'image_06822.jpg',
#  'image_06823.jpg',
#  'image_06824.jpg',
#  'image_06825.jpg',
#  'image_06826.jpg',
#  'image_06827.jpg',
#  'image_06828.jpg',
#  'image_06829.jpg',
#  'image_06830.jpg',
#  'image_06831.jpg',
#  'image_06832.jpg',
#  'image_06833.jpg',
#  'image_06834.jpg',
#  'image_06835.jpg',
#  'image_06837.jpg',
#  'image_06838.jpg',
#  'image_06839.jpg',
#  'image_06840.jpg',
#  'image_06841.jpg',
#  'image_06842.jpg',
#  'image_06843.jpg',
#  'image_06844.jpg',
#  'image_06845.jpg',
#  'image_06846.jpg',
#  'image_06848.jpg',
#  'image_08048.jpg',
#  'image_08049.jpg',
#  'image_08050.jpg',
#  'image_08051.jpg',
#  'image_08052.jpg',
#  'image_08053.jpg',
#  'image_06571.jpg',
#  'image_06573.jpg',
#  'image_06574.jpg',
#  'image_06575.jpg',
#  'image_06576.jpg',
#  'image_06577.jpg',
#  'image_06578.jpg',
#  'image_06579.jpg',
#  'image_06581.jpg',
#  'image_06585.jpg',
#  'image_06586.jpg',
#  'image_06587.jpg',
#  'image_06588.jpg',
#  'image_06589.jpg',
#  'image_06590.jpg',
#  'image_06591.jpg',
#  'image_06592.jpg',
#  'image_06594.jpg',
#  'image_06595.jpg',
#  'image_06596.jpg',
#  'image_06597.jpg',
#  'image_06598.jpg',
#  'image_06599.jpg',
#  'image_06600.jpg',
#  'image_06601.jpg',
#  'image_06602.jpg',
#  'image_06603.jpg',
#  'image_06604.jpg',
#  'image_06605.jpg',
#  'image_06606.jpg',
#  'image_06607.jpg',
#  'image_06608.jpg',
#  'image_06609.jpg',
#  'image_06610.jpg',
#  'image_06487.jpg',
#  'image_06488.jpg',
#  'image_06489.jpg',
#  'image_06490.jpg',
#  'image_06491.jpg',
#  'image_06492.jpg',
#  'image_06493.jpg',
#  'image_06494.jpg',
#  'image_06495.jpg',
#  'image_06496.jpg',
#  'image_06499.jpg',
#  'image_06502.jpg',
#  'image_06503.jpg',
#  'image_06504.jpg',
#  'image_06505.jpg',
#  'image_06507.jpg',
#  'image_06508.jpg',
#  'image_06509.jpg',
#  'image_06510.jpg',
#  'image_06511.jpg',
#  'image_06512.jpg',
#  'image_06513.jpg',
#  'image_06515.jpg',
#  'image_06517.jpg',
#  'image_06518.jpg',
#  'image_06519.jpg',
#  'image_06520.jpg',
#  'image_06521.jpg',
#  'image_06522.jpg',
#  'image_06523.jpg',
#  'image_06524.jpg',
#  'image_06525.jpg',
#  'image_06527.jpg',
#  'image_06850.jpg',
#  'image_06851.jpg',
#  'image_06852.jpg',
#  'image_06853.jpg',
#  'image_06854.jpg',
#  ...]

# %%
data_dir = './flower_data/'
train_dir = data_dir + '/train_filelist'
valid_dir = data_dir + '/val_filelist'

# %% [markdown]
# #### 任务4：把上面那几个事得写在一起
# - 1.注意要使用from torch.utils.data import Dataset, DataLoader
# - 2.类名定义class FlowerDataset(Dataset)，其中FlowerDataset可以改成自己的名字
# - 3.def __init__(self, root_dir, ann_file, transform=None):咱们要根据自己任务重写
# - 4.def __getitem__(self, idx):根据自己任务，返回图像数据和标签数据

# %%
from torch.utils.data import Dataset, DataLoader


class FlowerDataset(Dataset):
    def __init__(self, root_dir, ann_file, transform=None):
        self.ann_file = ann_file
        self.root_dir = root_dir
        self.img_label = self.load_annotations()
        self.img = [os.path.join(self.root_dir, img) for img in list(self.img_label.keys())]
        self.label = [label for label in list(self.img_label.values())]
        self.transform = transform

    def __len__(self):
        return len(self.img)

    def __getitem__(self, idx):
        image = Image.open(self.img[idx])
        label = self.label[idx]
        if self.transform:
            #特征图像处理
            image = self.transform(image)
        label = torch.from_numpy(np.array(label))
        return image, label

    def load_annotations(self):
        data_infos = {}
        with open(self.ann_file) as f:
            samples = [x.strip().split(' ') for x in f.readlines()]
            for filename, gt_label in samples:
                data_infos[filename] = np.array(gt_label, dtype=np.int64)
        return data_infos

# %% [markdown]
# #### 任务5：数据预处理(transform)

# %%
data_transforms = {
    'train':
        transforms.Compose([
            transforms.Resize(64),
            transforms.RandomRotation(45),  #随机旋转，-45到45度之间随机选
            transforms.CenterCrop(64),  #从中心开始裁剪
            transforms.RandomHorizontalFlip(p=0.5),  #随机水平翻转 选择一个概率概率
            transforms.RandomVerticalFlip(p=0.5),  #随机垂直翻转
            transforms.ColorJitter(brightness=0.2, contrast=0.1, saturation=0.1, hue=0.1),
            #参数1为亮度，参数2为对比度，参数3为饱和度，参数4为色相
            transforms.RandomGrayscale(p=0.025),  #概率转换成灰度率，3通道就是R=G=B
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  #均值，标准差
        ]),
    'valid':
        transforms.Compose([
            transforms.Resize(64),
            transforms.CenterCrop(64),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
}

# %% [markdown]
# #### 任务6：根据写好的class FlowerDataset(Dataset):来实例化咱们的dataloader

# %%
train_dataset = FlowerDataset(root_dir=train_dir, ann_file='./flower_data/train.txt',
                              transform=data_transforms['train'])
val_dataset = FlowerDataset(root_dir=valid_dir, ann_file='./flower_data/val.txt', transform=data_transforms['valid'])

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=True)

# %%
len(train_dataset)
# Out:
# 6552

# %% [markdown]
# #### 任务7：用之前先试试，整个数据和标签对应下，看看对不对

# %%
# %matplotlib inline
image, label = next(iter(train_loader))
sample = image[0].squeeze()
sample = sample.permute((1, 2, 0)).numpy()
sample *= [0.229, 0.224, 0.225]
sample += [0.485, 0.456, 0.406]
sample = np.clip(sample, 0, 1)
print(sample.shape)
print(sample)
plt.imshow(sample)
# Out:
# (64, 64, 3)
# [[[1.9215684e-01 9.0196073e-02 9.4117656e-02]
#   [2.7058825e-01 5.0980389e-02 1.0588236e-01]
#   [5.9607846e-01 3.5294145e-02 2.1960786e-01]
#   ...
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]]
#
#  [[2.5490198e-01 3.9215684e-02 9.4117656e-02]
#   [4.1960785e-01 3.5294145e-02 1.6470590e-01]
#   [6.5490198e-01 3.1372547e-02 2.3921570e-01]
#   ...
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]]
#
#  [[2.6666668e-01 1.9607842e-02 1.0980393e-01]
#   [4.1176471e-01 2.3529440e-02 1.5294121e-01]
#   [6.2745100e-01 2.7450979e-02 2.3137257e-01]
#   ...
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]]
#
#  ...
#
#  [[0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   ...
#   [1.2549017e-01 7.4509799e-02 6.2745109e-02]
#   [1.6862743e-01 9.8039240e-02 7.0588246e-02]
#   [2.0784311e-01 8.6274534e-02 8.6274520e-02]]
#
#  [[0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   ...
#   [1.3333331e-01 9.4117641e-02 7.0588246e-02]
#   [1.5686272e-01 1.3725492e-01 9.8039225e-02]
#   [1.9999997e-01 1.0196078e-01 8.2352951e-02]]
#
#  [[0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   [0.0000000e+00 2.9563903e-08 1.1682510e-08]
#   ...
#   [1.6862743e-01 1.1372548e-01 9.4117656e-02]
#   [1.4117645e-01 1.2549022e-01 9.8039225e-02]
#   [1.6470586e-01 1.3333336e-01 1.0588236e-01]]]
